# %%
from tkinter import filedialog, Tk, Button
from PIL import Image
root = Tk() ## 加上root=Tk() root.mainloop()窗口才能正常关闭

b = Button(root, text='退出', command = root.quit)
Fpath = filedialog.askopenfilename()
filename = Fpath
print(filename)
im = Image.open(filename)
w, h = im.size
im.thumbnail((w//2, h//2))
display(im)
b.pack()

root.mainloop()
root.destroy()
# Out:
# F:/Users/zhong/Desktop/微信文件/fab41f5faa850e664be3db7a333a326.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x286 at 0x2DCDB6AF520>
