# %%
from PIL import Image
img = Image.open('test.gif')
try:
    while True:
        display(img)
        img.seek(img.tell()+1)
except:
    print('end')
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=253x253 at 0x1F3CE052CD0>
# <PIL.GifImagePlugin.GifImageFile image mode=P size=253x253 at 0x1F3CE052CD0>
# <PIL.GifImagePlugin.GifImageFile image mode=P size=253x253 at 0x1F3CE052CD0>
# <PIL.GifImagePlugin.GifImageFile image mode=P size=253x253 at 0x1F3CE052CD0>
# end
