# %%
from tkinter import filedialog, Tk, Button
from PIL import Image
root = Tk() ## 加上root=Tk() root.mainloop()窗口才能正常关闭

b = Button(root, text='退出', command = root.quit)
Fpath = filedialog.askopenfilename()
filename = Fpath
print(filename)
im = Image.open(filename)
w, h = im.size
im.thumbnail((w//5, h//5))
display(im)
b.pack()

root.mainloop()
root.destroy()  # 加上这句 按退出键不会卡
# Out:
# F:/Users/zhong/Desktop/微信文件/test.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=185x185 at 0x275180D01C0>
